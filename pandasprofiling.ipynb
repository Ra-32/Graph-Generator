# %% [markdown]
# <a href="https://colab.research.google.com/github/Ra-32/Graph-Generator/blob/main/pandasprofiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/titanic.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 306         1198         0       1  Allison, Mr. Hudson Joshua Creighton
# 140         1032         1       3           Goodwin, Miss. Jessie Allis
# 194         1086         0       2         Drew, Master. Marshall Brines
# 204         1096         0       2              Andrew, Mr. Frank Thomas
# 250         1142         1       2                 West, Miss. Barbara J
#
#         Sex    Age  SibSp  Parch      Ticket    Fare    Cabin Embarked
# 306    male  30.00      1      2      113781  151.55  C22 C26        S
# 140  female  10.00      5      2     CA 2144   46.90      NaN        S
# 194    male   8.00      0      2       28220   32.50      NaN        S
# 204    male  25.00      0      0  C.A. 34050   10.50      NaN        S
# 250  female   0.92      1      2  C.A. 34651   27.75      NaN        S

# %% [markdown]
# Pandas profiling is used for giveing the report of dataset and that report used to data analysis

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.8.1
#     Uninstalling visions-0.8.1:
#       Successfully uninstalled visions-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires visions[type_image_path]<0.8.2,>=0.7.5, but you have visions 0.7.4 which is incompatible.
# ...

# %%
# !pip uninstall  pandas-profiling==3.6.6
# Out:
# Found existing installation: pandas-profiling 3.2.0
# Uninstalling pandas-profiling-3.2.0:
#   Would remove:
#     /usr/local/bin/pandas_profiling
#     /usr/local/lib/python3.11/dist-packages/pandas_profiling-3.2.0.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/pandas_profiling/*
# Proceed (Y/n)? y
#   Successfully uninstalled pandas-profiling-3.2.0

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.
# ...

# %%
from ydata_profiling import ProfileReport # Or from pandas_profiling import ProfileReport if using the older version
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_html()

profile.to_file("your_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
